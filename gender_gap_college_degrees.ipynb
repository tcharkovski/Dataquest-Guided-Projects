# %% [markdown]
# # Visualizing the gender gap in college degrees
# __The visualization is based on data from 1968 to 2011__ <br/>
# __Degrees awarded are in percentages__

# %%
# Importing the modules to be used in this project
# %matplotlib inline # This is so the charts would be displayed in the same cell.
import pandas as pd
import matplotlib.pyplot as plt

 # Read the csv file into a dataframe
women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')

# Set the color (in the range between 0 and 1)
cb_dark_blue = (0/255,107/255,164/255) 
cb_orange = (255/255, 128/255, 14/255)

# Creating a list of majors to guide making of plots
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics'] 
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture', 'Business', 'Architecture']

# Create a figure container for the plots
fig = plt.figure(figsize=(20, 25))

# A for loop to create 6 line plots of STEM degree categories
for sp in range(0,6):
    ax = fig.add_subplot(6,3,3*sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    
    # To set spines visible or not, in this case; not visible.
    ax.spines["right"].set_visible(False)     
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    
    # To set the limit of the x axis and y axis
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    
    # To make only 0 and 100 visible on any specified axis, in this case; y axis
    ax.set_yticks([0,100])
    
    # To set the title of the chart
    ax.set_title(stem_cats[sp])
    
    # A method to set the parameter of the tick
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    
    # To draw a horizontal line on a plot at a specified location 
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
        
    # to write a text on the chart at a given location, useful to act as legend
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        ax.tick_params(labelbottom='on')

# Check comments above for hints to what's going on below where appropriate
for sp in range(0,5):
    ax = fig.add_subplot(6,3,3*sp+2)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100 - women_degrees[lib_arts_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0, 100)
    ax.set_yticks([0,100])
    ax.set_title(lib_arts_cats[sp])
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off')
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
    
    if sp == 4:
        ax.tick_params(labelbottom='on')
        
    if sp == 0:
        ax.text(2005, 23, 'Men')
        ax.text(2005, 77, 'Women')
        
for sp in range(0,6):
    ax = fig.add_subplot(6,3,3*sp+3)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100 - women_degrees[other_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0, 100)
    ax.set_yticks([0,100])
    ax.set_title(other_cats[sp])
    ax.tick_params(bottom='off', top='off', left='off', right='off', labelbottom='off')
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
        
    if sp == 0:
        ax.text(2007, 8, 'Men')
        ax.text(2005, 88, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2005, 35, 'Women')
        ax.tick_params(labelbottom='on')
        
# To save the generated plot as an image, must be called before plt.show()        
plt.savefig('gender_degrees.png')
plt.show()

# %% [markdown]
# # Conclusion
# > * __Men across the years from 1968 to 2011 men have a higher percentage of Engineering, Computer Science, Physical Sciences, Architecture and Math and Statistics Compared to women who all have below 50%.__
# * __Women have a higher percentage of college degrees awarded to them compared to their male counterparts in Health Professions, Foreign Languages, English, Communications and Journalism, Education, Art and Performance across the year 1968 to 2011.__
# * __ In Social Science and History women had the higher percentage of college degrees awared to them between 1968 to 1998 and  there seems to be a balance from then to 2010.__
# * __From 1968 to 1990 Biology saw men being awarded college degrees at a higher percentage than women but after 1990 women overtook men by being awarded college degrees.__
# * __Agriculture was dominated by men from 1968 till 2010 where there was a balance between men and women in degrees awarded.__
# * __Men dominated the Business major in degrees awarded from 1968 to 1998 but from then on there has been a balance in degrees awarded between men and women.__
# * __From 1968 to 1980 men dominated degrees awarded in Communications and Journalism but from then on till 2010 women have higher degrees awarded to them than men.__
